# %% [markdown]
# # 2. Run some training loops

# %%
# %load_ext autoreload
# %autoreload 2

import os
import yaml

import numpy as np
import pandas as pd
import yaml
import torch
from torch_geometric.data import Data
import matplotlib.pyplot as plt

from time import time as tt
